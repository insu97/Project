# %%
import pandas as pd

# %%
pd.read_csv("../data/FM2024_field_player_info.csv").head()
# Out:
#               Name  Age               Position(s)   Foot  Height Weight  \
# 0  Kevin De Bruyne   32    MC, MR, ML, AMCMC, AMC  Right  181 CM  68 KG
# 1   Erling Haaland   22                      STST   Left  195 CM  94 KG
# 2    Kylian Mbappé   24       AMR, AML, STAML, ST  Right  178 CM  73 KG
# 3     Lionel Messi   36  AMR, AMC, STAMR, AMC, ST   Left  169 CM  67 KG
# 4       Harry Kane   29                 AMC, STST  Right  188 CM  86 KG
#
#               Club           Wages  corners  crossing  ...  vision  work-rate  \
# 0  Manchester City    € 397,800 pw       70        95  ...      99         75
# 1  Manchester City    € 397,800 pw       35        50  ...      70         65
# 2              PSG  € 1,038,960 pw       65        60  ...      75         60
# 3      Inter Miami    € 368,240 pw       75        75  ...      99         45
# 4        FC Bayern    € 423,280 pw       45        75  ...      95         80
#
# ...
