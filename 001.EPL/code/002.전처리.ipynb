# %%
import pandas as pd

# %%
df = pd.read_csv("../data/full_data.csv", low_memory=False)

# %% [markdown]
# # 데이터 선별 및 전처리

# %%
use_columns = []

# %%
df.head()
# Out:
#   Div      Date  HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  ...  \
# 0  E0  19/08/00  Charlton       Man City     4     0   H     2     0   H  ...
# 1  E0  19/08/00   Chelsea       West Ham     4     2   H     1     0   H  ...
# 2  E0  19/08/00  Coventry  Middlesbrough     1     3   A     1     1   D  ...
# 3  E0  19/08/00     Derby    Southampton     2     2   D     1     2   A  ...
# 4  E0  19/08/00     Leeds        Everton     2     0   H     2     0   H  ...
#
#    AvgC<2.5 AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0       NaN  NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN
# 1       NaN  NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN
# 2       NaN  NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN
# 3       NaN  NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN
# 4       NaN  NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN
#
#    AvgCAHA
# 0      NaN
# ...

# %%
len(df)
# Out:
# 9120

# %%
df['Div'].value_counts()
# Out:
# Div
# E0    9120
# Name: count, dtype: int64

# %%
df.drop(columns=['Div'], inplace = True)

# %%
df.head()
# Out:
#        Date  HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  19/08/00  Charlton       Man City     4     0   H     2     0   H
# 1  19/08/00   Chelsea       West Ham     4     2   H     1     0   H
# 2  19/08/00  Coventry  Middlesbrough     1     3   A     1     1   D
# 3  19/08/00     Derby    Southampton     2     2   D     1     2   A
# 4  19/08/00     Leeds        Everton     2     0   H     2     0   H
#
#    Attendance  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     20043.0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 1     34914.0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 2     20624.0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 3     27223.0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
# 4     40010.0  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0      NaN      NaN      NaN
# ...

# %%
use_columns.extend(['Date', 'HomeTeam', 'AwayTeam'])

# %%
use_columns
# Out:
# ['Date', 'HomeTeam', 'AwayTeam']
